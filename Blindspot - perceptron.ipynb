# %%
import pandas as pd

features = pd.read_csv('data/linsep-traindata.csv').values
classes = pd.read_csv('data/linsep-trainclass.csv').values

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Perceptron

X_train, X_test, y_train, y_test = train_test_split(features, classes)

perceptron = Perceptron(max_iter=100, tol=None)
perceptron.fit(X_train, y_train.ravel())
# Out:
# Perceptron(alpha=0.0001, class_weight=None, eta0=1.0, fit_intercept=True,
#       max_iter=100, n_iter=None, n_jobs=1, penalty=None, random_state=0,
#       shuffle=True, tol=None, verbose=0, warm_start=False)

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test.ravel(), perceptron.predict(X_test)))
# Out:
# [[14  0]
#  [ 0 11]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test.ravel(), perceptron.predict(X_test)))
# Out:
#              precision    recall  f1-score   support
#
#          -1       1.00      1.00      1.00        14
#           1       1.00      1.00      1.00        11
#
# avg / total       1.00      1.00      1.00        25

# %%
import matplotlib.pyplot as plt

plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Perceptron classifier - all data')
plt.scatter(features[:, 0], features[:, 1], c=perceptron.predict(features))
